# %% [markdown]
# #### Database connection with Microsoft SQL Server

# %%
import pyodbc

# %%
conn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=digitelt32;"
                      "Database=swiftalm;"
                      "Username=swiftalm;"
                      "Password=111111;"
                      "Trusted_Connection=yes;")
cursor = conn.cursor()
query="SELECT * FROM swiftalm.Enterpriseuser"
cursor.execute(query)

for row in cursor:
    print('row = %r' % (row,))

conn.close()
# Out:
# row = (-3, -1, 'System', '#System', '', None, None, datetime.datetime(2008, 2, 19, 0, 0), None, None, 'Open', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '0', None, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'GMT', 'English', -1, None, None, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (-2, -2, 'Timesheet', '-2', 'Local', None, None, datetime.datetime(2008, 2, 19, 0, 0), None, None, 'Open', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '0', None, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'GMT', 'English', -1, None, None, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (-1, -1, 'Template', 'x', 'User', None, None, datetime.datetime(2008, 2, 19, 0, 0), None, None, 'Open', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '0', None, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'GMT', 'English', -1, None, 1, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30000021, 30000001, 'Admin', 'SALM_saasadmin', 'SAAS', 'noemail@noemail.com', datetime.datetime(2009, 6, 22, 11, 31, 49), datetime.datetime(2015, 11, 17, 14, 2, 18, 693000), b'\x1f\x98(\t\xd9\xd5\xeew#\xad\xd2\xa0k\xe0b\x94', datetime.datetime(2016, 7, 29, 0, 56, 9, 243000), 'Locked', 'Its password', 'password', Decimal('100.00'), 'Digite Infotech Pvt Ltd', None, None, None, None, '--None--', None, None, None, None, None, None, None, None, '', '--None--', '--None--', '30005685', 23, 'Y', None, None, None, None, None, None, 'N', 'en_US', 'en_US', 'en_US', 'IST', 'English', 30000002, 'Open', 0, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005686, 30000001, 'Martin', 'SALM_amartin', 'Alex', 'noemail@noemail.com', datetime.datetime(2009, 6, 24, 18, 43, 32), datetime.datetime(2010, 1, 13, 7, 5, 29), None, None, 'Locked', 'password', 'password', Decimal('1.00'), None, None, None, None, None, 'KEY_United_States', None, None, None, None, None, None, None, None, '1099', None, '0', '0', 6, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'GMT', 'English', 30000002, 'Open', 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005687, 30000001, 'Beaver', 'SALM_cbeaver', 'Carl', 'noemail@noemail.com', datetime.datetime(2009, 6, 24, 18, 43, 32), datetime.datetime(2010, 6, 17, 15, 38), None, datetime.datetime(2011, 6, 17, 15, 38), 'Locked', 'password', 'password', Decimal('1.00'), None, None, None, None, None, 'KEY_United_States', None, None, None, None, None, None, None, None, '2676', None, '0', '0', 7, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'GMT', 'English', 30000002, 'Open', 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005688, 30000001, 'Kailash', 'SALM_rkailash', 'Ravi', 'noemail@noemail.com', datetime.datetime(2009, 6, 24, 18, 43, 32), datetime.datetime(2009, 12, 2, 2, 5, 25), None, datetime.datetime(2010, 12, 2, 2, 5, 25), 'Locked', 'password', 'password', Decimal('1.00'), None, None, None, None, None, 'KEY_United_States', None, None, None, None, None, None, None, None, '2342', None, '0', '0', 6, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'GMT', 'English', 30000002, 'Open', 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005690, 30000001, 'Maker', 'SALM_nmaker', 'Nancy', 'noemail@noemail.com', datetime.datetime(2009, 6, 24, 18, 43, 33), datetime.datetime(2014, 3, 25, 11, 41, 49, 983000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2015, 3, 25, 11, 41, 49, 983000), 'Locked', '111111', '111111', Decimal('1.00'), 'Zoomin Corporation', 'Technology Consultant', '64, Maple Avenue', 'Peoria', 'Illinois', 'KEY_India', '61656', None, None, '309-223-2210', None, None, '309-085-6523', None, '1983', 'Software', 'Engineering', '30005691', 19, None, None, '356, Highwater Plaza', 'Peoria', 'Illinois', 'KEY_United_States', '61656', None, 'en_US', 'en_US', 'en_US', 'GMT', 'English', 30000002, 'Open', 30000004, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005692, 30000001, 'Pegg', 'SALM_spegg', 'Simon', 'noemail@noemail.com', datetime.datetime(2009, 6, 24, 18, 43, 33), datetime.datetime(2014, 1, 22, 9, 0, 45, 743000), b'\xca]"\xba\x00<\xf2=', datetime.datetime(2015, 1, 12, 13, 21, 54, 513000), 'Locked', '222222', '222222', Decimal('1.00'), None, None, None, None, None, 'KEY_United_States', None, None, None, None, None, None, None, None, '2233', None, '0', '30005689', 12, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'GMT', 'English', 30000002, 'Open', 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005693, 30000001, 'Desai', 'SALM_ndesai', 'Nitin', 'noemail@noemail.com', datetime.datetime(2009, 6, 24, 18, 43, 33), datetime.datetime(2009, 10, 1, 16, 42, 10), None, datetime.datetime(2010, 10, 1, 13, 52, 31), 'Locked', '111111', '111111', Decimal('1.00'), None, None, None, None, None, 'KEY_United_States', None, None, None, None, None, None, None, None, '3565', None, '0', '0', 6, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'GMT', 'English', 30000002, 'Open', 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005694, 30000001, 'Hang', 'SALM_whang', 'Wan', 'noemail@noemail.com', datetime.datetime(2009, 6, 24, 18, 43, 34), datetime.datetime(2009, 11, 30, 10, 31, 7), None, datetime.datetime(2010, 11, 30, 10, 31, 7), 'Locked', 'password', 'password', Decimal('1.00'), None, None, None, None, None, 'KEY_United_States', None, None, None, None, None, None, None, None, '5690', None, '0', '0', 5, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'GMT', 'English', 30000002, 'Open', 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005695, 30000001, 'Verma', 'SALM_rverma', 'Richa', 'noemail@noemail.com', datetime.datetime(2009, 6, 24, 18, 43, 34), datetime.datetime(2010, 11, 8, 7, 56, 48), None, None, 'Locked', 'password', 'password', Decimal('1.00'), None, None, None, None, None, 'KEY_United_States', None, None, None, None, None, None, None, None, '1424', None, '0', '0', 6, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'GMT', 'English', 30000002, 'Open', 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005697, 30000001, 'Amundson', 'SALM_bamundson', 'Bryan', 'noemail@noemail.com', datetime.datetime(2009, 6, 24, 19, 6, 36), datetime.datetime(2014, 1, 2, 10, 46, 46, 503000), b'\x8bA\xe2\xd6\x9f\x05i\x04', datetime.datetime(2015, 1, 2, 10, 46, 46, 500000), 'Locked', '121212', '121212', Decimal('1.00'), None, None, None, None, None, 'KEY_United_States', None, None, None, None, None, None, None, None, '2111', None, None, '0', 6, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'GMT', 'English', 30000002, 'Open', 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005698, 30000001, 'Sutton', 'SALM_bsutton', 'Beth', 'noemail@noemail.com', datetime.datetime(2009, 8, 7, 11, 26, 3), datetime.datetime(2011, 2, 25, 1, 21, 8), None, None, 'Locked', '111111', '111111', Decimal('1.00'), None, None, None, None, None, 'KEY_United_States', None, None, None, None, None, None, None, None, None, None, None, '0', 2, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005699, 30000001, 'Ransel', 'SALM_monion', 'Marsh', 'noemail@noemail.com', datetime.datetime(2009, 10, 1, 14, 50, 57), datetime.datetime(2010, 11, 8, 7, 57, 4), None, datetime.datetime(2011, 11, 8, 7, 57, 4), 'Locked', 'password', 'password', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, None, None, None, '0', 1, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005700, 30000001, 'Meader', 'SALM_smeader', 'Shaun', 'noemail@noemail.com', datetime.datetime(2009, 10, 1, 20, 51, 36), datetime.datetime(2009, 11, 30, 10, 29, 36), None, datetime.datetime(2010, 11, 30, 10, 29, 36), 'Locked', 'password', 'password', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, None, None, None, '0', 1, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000008, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005701, 30000001, 'Clooney', 'SALM_rclooney', 'Roy', 'noemail@noemail.com', datetime.datetime(2009, 10, 1, 20, 52, 22), datetime.datetime(2009, 10, 1, 22, 4), None, datetime.datetime(2010, 10, 1, 22, 4), 'Locked', 'password', 'password', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, None, None, None, '0', 1, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000008, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005702, 30000001, 'Hall', 'SALM_mhall', 'Maggie', 'noemail@noemail.com', datetime.datetime(2009, 10, 1, 20, 53, 10), datetime.datetime(2009, 10, 1, 22, 13, 36), None, datetime.datetime(2010, 10, 1, 22, 13, 36), 'Locked', 'password', 'password', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, None, None, None, '0', 1, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005703, 30000001, 'Administrator', 'SALM_#demo_saasadmin', 'SaaS', 'noemail@noemail.com', datetime.datetime(2010, 7, 26, 15, 10, 30), datetime.datetime(2010, 7, 26, 15, 10, 30), None, None, 'Locked', None, None, Decimal('1.00'), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 1, None, 'Y', None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'GMT', 'English', 30000002, None, 0, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (30005704, 30000001, 'Administrator', 'SALM_#demo_saasadmin', 'SaaS', 'noemail@noemail.com', datetime.datetime(2010, 7, 26, 15, 13, 48), datetime.datetime(2010, 7, 26, 15, 13, 48), None, None, 'Locked', None, None, Decimal('1.00'), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 1, None, 'Y', None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'GMT', 'English', 30000002, None, 0, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70001506, 30000001, 'Bidwai', 'sbidwai', 'Swapnil', 'noemail@noemail.com', datetime.datetime(2013, 10, 15, 12, 24, 25), datetime.datetime(2013, 10, 15, 12, 24, 25), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Locked', None, None, Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '111', None, None, '0', 1, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000005, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70004777, 30000001, 'Test', 'Test001', 'Test', 'noemail@noemail.com', datetime.datetime(2013, 12, 20, 9, 36, 43, 600000), datetime.datetime(2013, 12, 20, 9, 36, 43, 600000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Locked', None, None, Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', None, None, '0', 1, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000008, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70032519, 30000001, 'Virtual', '#Virtual', 'User', 'noemail@noemail.com', datetime.datetime(2014, 1, 15, 5, 23, 36, 403000), datetime.datetime(2014, 1, 15, 5, 24, 1, 217000), None, None, 'Locked', '', '', Decimal('2.00'), None, None, None, None, None, None, None, None, None, None, None, None, None, None, '', None, None, '0', 1, None, 'Y', None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', '', 'English', 30000002, None, 0, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70037978, 30000001, 'Victor', 'jvictor', 'Julia', 'noemail@noemail.com', datetime.datetime(2014, 1, 16, 12, 58, 5, 457000), datetime.datetime(2014, 1, 16, 16, 7, 29, 80000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2015, 1, 16, 16, 7, 29, 80000), 'Locked', '111111', '111111', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', None, None, '0', 1, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000005, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70037993, 30000001, 'Frank', 'jfrank', 'James', 'noemail@noemail.com', datetime.datetime(2014, 1, 16, 13, 2, 49, 663000), datetime.datetime(2014, 1, 16, 15, 54, 31, 227000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2015, 1, 16, 15, 54, 31, 223000), 'Locked', '111111', '111111', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', None, None, '0', 1, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000011, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70038004, 30000001, 'Franklin', 'jfranklin', 'Jessica', 'noemail@noemail.com', datetime.datetime(2014, 1, 16, 13, 3, 29, 173000), datetime.datetime(2014, 1, 16, 15, 55, 9, 617000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2015, 1, 16, 15, 55, 9, 617000), 'Locked', '111111', '111111', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', None, None, '0', 1, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000008, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70038046, 30000001, 'Ravichandran', 'sravi', 'Suraj', 'noemail@noemail.com', datetime.datetime(2014, 1, 16, 15, 50, 16, 863000), datetime.datetime(2014, 1, 16, 15, 56, 2, 607000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2015, 1, 16, 15, 56, 2, 603000), 'Locked', '111111', '111111', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', None, None, '0', 1, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000005, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70038057, 30000001, 'Gasguet', 'rgasguet', 'Richard', 'noemail@noemail.com', datetime.datetime(2014, 1, 16, 15, 51, 22, 943000), datetime.datetime(2014, 1, 16, 15, 56, 36, 97000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2015, 1, 16, 15, 56, 36, 97000), 'Locked', '111111', '111111', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', None, None, '0', 1, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000005, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70038068, 30000001, 'Hall', 'mhall', 'Maggie', 'noemail@noemail.com', datetime.datetime(2014, 1, 16, 15, 52, 20, 787000), datetime.datetime(2014, 1, 16, 15, 53, 37, 690000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2015, 1, 16, 15, 53, 37, 687000), 'Locked', '111111', '111111', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', None, None, '0', 1, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000005, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70039413, 30000001, 'Menon', 'U11418', 'Raghunandan', 'noemail@noemail.com', datetime.datetime(2014, 1, 17, 8, 57, 4, 933000), datetime.datetime(2014, 1, 23, 12, 0, 33, 610000), b'\xb7\x82\xa8+/Y$\xc3U\x98\xbbr\xf1\xa3\xa7}', datetime.datetime(2015, 1, 23, 12, 0, 33, 610000), 'Locked', 'Program Name', 'OptimUS Prime', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U11418', None, None, '0', 1, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000005, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70040884, 30000001, 'Eapen', 'U10712', 'Binju', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 38, 910000), datetime.datetime(2014, 2, 3, 8, 35, 23, 647000), b'\x06\xef\xebn\xb4s\xb4~:kB\xb3\xfduF\xcc', datetime.datetime(2015, 2, 3, 8, 35, 23, 630000), 'Locked', 'first dog', 'digby', Decimal('0.00'), None, None, None, None, None, 'KEY_United_States', None, None, None, None, None, None, None, None, 'U10712', '0', '0', '0', 2, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70040896, 30000001, 'Thomas', 'U19624', 'Savitha', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 39, 250000), datetime.datetime(2014, 3, 6, 9, 58, 58, 840000), b'\xf7\xe8<:\xb08\xec:', datetime.datetime(2015, 3, 6, 9, 58, 58, 840000), 'Locked', 'What is your password', 'forgot', Decimal('0.00'), None, None, None, None, None, 'KEY_United_States', None, None, None, None, None, None, None, None, 'U19624', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70040908, 30000001, 'Rajasekaran', 'U22890', 'Vijay', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 39, 527000), datetime.datetime(2014, 1, 18, 7, 21, 39, 693000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U22890', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70040920, 30000001, 'Jose', 'U23058', 'Akhila', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 39, 807000), datetime.datetime(2014, 3, 6, 6, 32, 4, 723000), b'\xf3\xf9\xbct\xee\xb4=6', datetime.datetime(2015, 3, 6, 6, 32, 4, 717000), 'Locked', 'what is your password', 'password', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U23058', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70040932, 30000001, 'Kannan', 'U23208', 'Dhanesh Kumar', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 40, 97000), datetime.datetime(2014, 3, 6, 6, 28, 4, 217000), b'\x1fB\xc6#\xfe\xc7\x8d%n\x19]\x8d\x99X1\xd1', datetime.datetime(2015, 3, 6, 6, 28, 4, 200000), 'Locked', 'Your Town', 'Bangalore', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U23208', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70040944, 30000001, 'Vattapara Sasindran', 'U23608', 'Amalraj', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 40, 367000), datetime.datetime(2014, 1, 18, 7, 21, 40, 527000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U23608', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70040956, 30000001, 'Mohan', 'U23869', 'Shaji', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 40, 630000), datetime.datetime(2014, 2, 11, 7, 2, 23, 577000), b'\xbc\xdc\x8508e\xc8m\x02u\x13\n\xdaW\xb4\xf0', datetime.datetime(2015, 2, 11, 7, 2, 23, 577000), 'Locked', 'DevSha1', 'DevSha1', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U23869', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70040968, 30000001, 'Radhakrishnan Sumambika', 'U25149', 'Deepu', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 40, 920000), datetime.datetime(2014, 3, 6, 6, 32, 28, 493000), b'\x18cq\xa9\x99\x8b+\xf8\xfe\xb9Y\xb7\xd4d/\xcb', datetime.datetime(2015, 3, 6, 6, 32, 28, 493000), 'Locked', 'name of pet', 'storm', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U25149', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70040980, 30000001, 'James', 'U26984', 'Jomy', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 41, 220000), datetime.datetime(2014, 3, 6, 6, 36, 2, 233000), b'\x83a\xfcpcW\xc8\x88m@f\x9a\x98\xf0\x1c2', datetime.datetime(2015, 3, 6, 6, 36, 2, 233000), 'Locked', 'Name', 'jomy', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U26984', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70040992, 30000001, 'Anand', 'U26986', 'Abhishek', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 41, 503000), datetime.datetime(2014, 1, 18, 7, 21, 41, 667000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U26986', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041004, 30000001, 'Manilal', 'U27684', 'Priya', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 41, 780000), datetime.datetime(2014, 1, 18, 7, 21, 41, 947000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U27684', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041016, 30000001, 'Nagarajan', 'U29701', 'Pradeep', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 42, 57000), datetime.datetime(2014, 3, 6, 7, 51, 47, 970000), b'\x9a\xd1\xecn\x9ei\x0e9\xb1\xe0\x92\xbd\xb5\x90P!', datetime.datetime(2015, 3, 6, 7, 51, 47, 963000), 'Locked', 'what is your mobile number', '9645599370', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U29701', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041028, 30000001, 'Muhamed Kunju Habeeba Beevi', 'U30313', 'Rihas', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 42, 343000), datetime.datetime(2014, 1, 18, 7, 21, 42, 507000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U30313', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041040, 30000001, 'Mahesh', 'U33224', 'Ganesh Raj', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 42, 610000), datetime.datetime(2014, 1, 18, 7, 21, 42, 783000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U33224', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041052, 30000001, 'Goyal', 'U33348', 'Aman', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 42, 893000), datetime.datetime(2014, 1, 18, 7, 21, 43, 90000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U33348', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041064, 30000001, 'Prasadchandran', 'U12834', 'Deleep', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 43, 193000), datetime.datetime(2014, 1, 18, 7, 21, 43, 357000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U12834', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041076, 30000001, 'Sathish Kumar', 'U18214', 'Leo', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 43, 463000), datetime.datetime(2014, 1, 18, 7, 21, 43, 627000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U18214', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041088, 30000001, 'Mandarapu', 'U19462', 'Nagaraj', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 43, 743000), datetime.datetime(2014, 1, 18, 7, 21, 43, 930000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U19462', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041100, 30000001, 'Karunanandan', 'U20047', 'Surendar', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 44, 37000), datetime.datetime(2014, 1, 18, 7, 21, 44, 193000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U20047', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041112, 30000001, 'Balasubramanian', 'U20088', 'Krishnan', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 44, 297000), datetime.datetime(2014, 1, 27, 5, 51, 35, 863000), b'\xb4,\xa4\xec8\xd6\xc7\xd2\xfe\xb9Y\xb7\xd4d/\xcb', datetime.datetime(2015, 1, 27, 5, 51, 35, 847000), 'Locked', 'Favourite Sports', 'cricket', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U20088', '0', '0', '0', 2, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, 'Open', 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041124, 30000001, 'Patil', 'U20308', 'Kiran', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 44, 580000), datetime.datetime(2014, 1, 18, 7, 21, 44, 747000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U20308', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041136, 30000001, 'Thumma', 'U20331', 'Amani', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 44, 880000), datetime.datetime(2014, 1, 18, 7, 21, 45, 43000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U20331', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041148, 30000001, 'Dey', 'U20355', 'Manoj', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 45, 147000), datetime.datetime(2014, 1, 18, 7, 21, 45, 307000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U20355', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041160, 30000001, 'Augustine', 'U20905', 'Alfred', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 45, 433000), datetime.datetime(2014, 3, 5, 12, 6, 11, 160000), b'c=XY\xd8d\xc5\x0b\xd9\x1bG\xbc\x01\xa2ON', datetime.datetime(2015, 3, 5, 12, 6, 11, 143000), 'Locked', 'what is your Pets name', 'misha', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U20905', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041172, 30000001, 'Sreekantan Nair', 'U21224', 'Rajesh', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 45, 703000), datetime.datetime(2014, 2, 27, 13, 31, 2, 17000), b'w\xf0K\xeeL\x7f\x0c\xa0\x19)\t\xf8\xf4\xb4\xbeJ', datetime.datetime(2015, 2, 27, 13, 31, 2), 'Locked', 'Mob no. spouse', '9645101214', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U21224', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041184, 30000001, 'Setty', 'U22000', 'Mahendra', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 45, 997000), datetime.datetime(2014, 1, 18, 7, 21, 46, 157000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U22000', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041196, 30000001, 'Barba', 'U24125', 'Alex', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 46, 263000), datetime.datetime(2014, 1, 18, 7, 21, 46, 423000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U24125', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041208, 30000001, 'SINGH', 'U24376', 'GURDEV', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 46, 540000), datetime.datetime(2014, 1, 18, 7, 21, 46, 707000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U24376', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041220, 30000001, 'Raghavan', 'U24528', 'Kamal', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 46, 840000), datetime.datetime(2014, 1, 18, 7, 21, 47, 7000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U24528', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041232, 30000001, 'Chenniappan', 'U24564', 'Velumani', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 47, 123000), datetime.datetime(2014, 1, 18, 7, 21, 47, 283000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U24564', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041244, 30000001, 'Mohammed Saleem', 'U25496', 'Ibnu', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 47, 390000), datetime.datetime(2014, 1, 18, 7, 21, 47, 553000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U25496', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041256, 30000001, 'Ajayan Vasumathy', 'U26553', 'Anupama', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 47, 660000), datetime.datetime(2014, 1, 18, 7, 21, 47, 830000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U26553', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041268, 30000001, 'Munuswamy Rajagopal', 'U26775', 'Ramesh', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 47, 940000), datetime.datetime(2014, 1, 18, 7, 21, 48, 133000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U26775', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041280, 30000001, 'Ellams', 'U26782', 'Jibril', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 48, 257000), datetime.datetime(2014, 1, 18, 7, 21, 48, 420000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U26782', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041292, 30000001, 'Muthusamy', 'U26870', 'Vijayakumar', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 48, 540000), datetime.datetime(2014, 1, 18, 7, 21, 48, 707000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U26870', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041304, 30000001, 'Gadula', 'U26979', 'Kiran', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 48, 823000), datetime.datetime(2014, 1, 18, 7, 21, 49, 3000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U26979', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041316, 30000001, 'Eemani', 'U26985', 'SubbaRao', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 49, 107000), datetime.datetime(2014, 1, 18, 7, 21, 49, 273000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U26985', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041328, 30000001, 'Shanmugham', 'U27083', 'Shanmuga Bipin', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 49, 383000), datetime.datetime(2014, 1, 18, 7, 21, 49, 553000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U27083', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041340, 30000001, 'Pili', 'U27155', 'Jimmy', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 49, 663000), datetime.datetime(2014, 1, 18, 7, 21, 49, 837000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U27155', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041352, 30000001, 'George', 'U27302', 'Johnson', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 49, 963000), datetime.datetime(2014, 1, 18, 7, 21, 50, 127000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U27302', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041364, 30000001, 'Facto', 'U27950', 'Mark Anthony', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 50, 230000), datetime.datetime(2014, 1, 18, 7, 21, 50, 397000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U27950', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041376, 30000001, 'Oyangorin', 'U27967', 'Vic Amiel', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 50, 507000), datetime.datetime(2014, 1, 18, 7, 21, 50, 677000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U27967', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041388, 30000001, 'Bautista', 'U27970', 'Mark David', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 50, 803000), datetime.datetime(2014, 1, 18, 7, 21, 51), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U27970', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041400, 30000001, 'Baldomero', 'U28343', 'Elwarl', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 51, 107000), datetime.datetime(2014, 1, 18, 7, 21, 51, 273000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U28343', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041412, 30000001, 'Voopalapati', 'U28567', 'Naveenkumar', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 51, 377000), datetime.datetime(2014, 1, 18, 7, 21, 51, 540000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U28567', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041424, 30000001, 'Paladugu', 'U28582', 'Veeranjaneyulu', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 51, 647000), datetime.datetime(2014, 1, 18, 7, 21, 51, 813000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U28582', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041436, 30000001, 'Mendoza', 'U29897', 'Jeremias', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 51, 940000), datetime.datetime(2014, 1, 18, 7, 21, 52, 103000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U29897', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041448, 30000001, 'Ankala', 'U29930', 'Giri', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 52, 207000), datetime.datetime(2014, 1, 18, 7, 21, 52, 370000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U29930', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041460, 30000001, 'Farooq Mohammed', 'U29984', 'Umar', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 52, 517000), datetime.datetime(2014, 1, 18, 7, 21, 52, 683000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U29984', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70041472, 30000001, 'Mohiuddin', 'U29986', 'Mohammed', 'noemail@noemail.com', datetime.datetime(2014, 1, 18, 7, 21, 52, 787000), datetime.datetime(2014, 1, 18, 7, 21, 52, 973000), b'\x8ae\xe0\xe8\x052\xb5\xfa\xfe\xb9Y\xb7\xd4d/\xcb', None, 'Locked', '', '', Decimal('0.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, 'U29986', '0', '0', '0', 1, None, None, None, None, None, '', None, None, 'en_US', 'en_US', 'en_US', 'EST', 'English', 30000002, None, 30000003, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# ...
# row = (70692390, 30000011, 'Deepak', 'deepak', 'Naik', 'deepak@digite.com', datetime.datetime(2015, 11, 5, 7, 13, 41, 140000), datetime.datetime(2016, 4, 16, 14, 16, 18, 690000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), '', '', '', '', '', '0', '', None, None, None, None, '', '', '', '', '--None--', '0', '0', 6, None, None, '', '', '', '--None--', '', '', 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, 'Open', 70532971, '', None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692391, 30000011, 'Amey', 'amey', 'Patil', 'amey@digite.com', datetime.datetime(2015, 11, 5, 7, 14, 25, 537000), datetime.datetime(2016, 6, 16, 11, 22, 47, 83000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2016, 12, 5, 15, 34, 17, 797000), 'Open', 'common', '111111', Decimal('1.00'), '', '', '', '', '', '0', '', None, None, None, None, '', '', '', '', '--None--', '0', '0', 5, None, None, '', '', '', '--None--', '', '', 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, 'Open', 70532973, '', None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692392, 30000011, 'Anand', 'abirla', 'Birla', 'abirla@digite.com', datetime.datetime(2015, 11, 5, 7, 14, 53, 607000), datetime.datetime(2016, 4, 16, 14, 16, 43, 463000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), '', '', '', '', '', '0', '', None, None, None, None, '', '', '', '', '--None--', '0', '0', 5, None, None, '', '', '', '--None--', '', '', 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, 'Open', 70532971, '', None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692393, 30000011, 'sheetal', 'sheetal', 'dindorkar', 'sheetal@digite.com', datetime.datetime(2015, 11, 5, 7, 15, 58, 643000), datetime.datetime(2015, 12, 29, 23, 55, 53, 473000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2016, 12, 8, 19, 29, 47, 740000), 'Open', 'common', '111111', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 4, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, None, 70532971, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692394, 30000011, 'Amit', 'amit', 'Pandey', 'apandey@digite.com', datetime.datetime(2015, 11, 5, 7, 16, 32, 367000), datetime.datetime(2015, 12, 29, 23, 50, 26, 823000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2016, 12, 15, 11, 34, 44, 820000), 'Open', 'common', '111111', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 4, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, None, 70532971, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692395, 30000011, 'Rahul', 'rahul', 'Mahant', 'rmahant@digite.com', datetime.datetime(2015, 11, 5, 7, 16, 58, 827000), datetime.datetime(2015, 12, 29, 23, 53, 40, 160000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 4, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, None, 70532971, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692396, 30000011, 'Deepali', 'deepali', 'Sonule', 'deepali@digite.com', datetime.datetime(2015, 11, 5, 7, 17, 24, 493000), datetime.datetime(2015, 12, 29, 23, 53, 39, 227000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 4, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, None, 70532971, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692397, 30000011, 'Roshini', 'roshini', 'S', 'roshini@digite.com', datetime.datetime(2015, 11, 5, 7, 18, 7, 110000), datetime.datetime(2015, 12, 29, 23, 55, 53, 233000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 4, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, None, 70532971, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692398, 30000011, 'Rajesh', 'rajesh', 'Rao', 'rrao@digite.com', datetime.datetime(2015, 11, 5, 7, 18, 43, 840000), datetime.datetime(2015, 12, 29, 23, 53, 40, 390000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 4, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, None, 70532971, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692399, 30000011, 'Rajesh', 'rkhond', 'Khond', 'rkhond@digite.com', datetime.datetime(2015, 11, 5, 7, 19, 7, 507000), datetime.datetime(2015, 12, 29, 23, 53, 40, 503000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 4, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, None, 70532971, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692400, 30000011, 'Mihir', 'mihir', 'Ved', 'mved@digite.com', datetime.datetime(2015, 11, 5, 7, 19, 37, 583000), datetime.datetime(2016, 4, 16, 14, 13, 58, 650000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), '', '', '', '', '', '0', '', None, None, None, None, '', '', '', '', '--None--', '0', '0', 5, None, None, '', '', '', '--None--', '', '', 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, 'Open', 70532971, '', None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692401, 30000011, 'Alpesh', 'alpesh', 'Chaurisya', 'alpesh@digite.com', datetime.datetime(2015, 11, 5, 7, 20, 45, 410000), datetime.datetime(2018, 10, 29, 0, 47, 21, 633000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2019, 10, 29, 0, 47, 21, 633000), 'Open', 'common', '111111', Decimal('1.00'), '', '', '', '', '', '0', '', None, None, None, None, '', '', '', '', '--None--', '0', '0', 4, None, None, '', '', '', '--None--', '', '', 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, 'Open', 70532971, '', None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692402, 30000011, 'Sowmya', 'sowmya', 'S', 'sowmya@digite.com', datetime.datetime(2015, 11, 5, 7, 21, 11, 713000), datetime.datetime(2015, 12, 29, 23, 55, 53, 640000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 4, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, 'Open', 70532971, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692403, 30000011, 'Akash', 'akash', 'K', 'akash@digite.com', datetime.datetime(2015, 11, 5, 7, 21, 32, 93000), datetime.datetime(2015, 12, 29, 23, 50, 26, 447000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 3, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, 'Open', 70532971, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692404, 30000011, 'Nishant', 'nishant', 'S', 'nishant@digite.com', datetime.datetime(2015, 11, 5, 7, 21, 56, 917000), datetime.datetime(2015, 12, 29, 23, 53, 39, 770000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 4, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, None, 70532971, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692405, 30000011, 'Aarif', 'aarif', 'S', 'aarif@digite.com', datetime.datetime(2015, 11, 5, 7, 22, 24, 777000), datetime.datetime(2016, 4, 19, 11, 28, 6, 630000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), '', '', '', '', '', '0', '', None, None, None, None, '', '', '', '', '--None--', '0', '30017826', 4, None, None, '', '', '', '--None--', '', '', 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, 'Open', 70532971, '', None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692406, 30000011, 'Vipul', 'vipul', 'N', 'vipul@digite.com', datetime.datetime(2015, 11, 5, 7, 22, 55, 833000), datetime.datetime(2015, 12, 29, 23, 55, 53, 947000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 4, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, None, 70532971, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692407, 30000011, 'Saurabh', 'saurabh', 'Khatri', 'skhatri@digite.com', datetime.datetime(2015, 11, 5, 7, 23, 22, 813000), datetime.datetime(2015, 12, 29, 23, 55, 53, 330000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 4, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, None, 70532971, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692408, 30000011, 'Surej', 'surej', 'S', 'surej@digite.com', datetime.datetime(2015, 11, 5, 7, 24, 3, 663000), datetime.datetime(2015, 12, 29, 23, 55, 53, 837000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 4, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, None, 70532971, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692409, 30000011, 'Yogesh', 'yogesh', 'S', 'yogesh@digite.com', datetime.datetime(2015, 11, 5, 7, 24, 28, 553000), datetime.datetime(2015, 12, 29, 23, 55, 54, 60000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 4, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, None, 70532971, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692410, 30000001, 'sheikh', 'test111', 'shahab', 'test@test.com', datetime.datetime(2015, 11, 16, 11, 34, 5, 927000), datetime.datetime(2015, 11, 16, 11, 34, 39, 627000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2016, 11, 15, 11, 34, 39, 627000), 'Locked', 'common', '111111', Decimal('1.00'), None, None, None, None, None, None, None, None, None, None, None, None, None, None, '', '--None--', '--None--', None, 1, None, None, None, None, None, None, None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 30000002, None, 30000004, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692411, 30000011, 'Omkar', 'omkar', 'Khamkar', 'omkar@digite.com', datetime.datetime(2015, 12, 7, 15, 39, 50, 697000), datetime.datetime(2016, 4, 16, 14, 12, 42, 910000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2016, 12, 6, 15, 41, 34, 263000), 'Open', 'recall question', '222222', Decimal('1.00'), '', '', '', '', '', '0', '', None, None, None, None, '', '', '', '', '--None--', '0', '0', 5, None, None, '', '', '', '--None--', '', '', 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, 'Open', 70532971, '', None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692412, 30000011, 'Parmeshwaram', 'param', 'CR', 'crparam@digite.com', datetime.datetime(2015, 12, 29, 19, 48, 56, 57000), datetime.datetime(2018, 11, 14, 12, 11, 13, 457000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2019, 11, 14, 12, 11, 13, 450000), 'Open', 'common', '111111', Decimal('1.00'), '', '', '', '', '', '0', '', None, None, None, None, '', '', '', '', '--None--', '0', '0', 3, None, None, '', '', '', '--None--', '', '', 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, 'Open', 70532964, '', None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692413, 30000011, 'Ashwini', 'ashwini', 'Lalit', 'alalit@digite.com', datetime.datetime(2015, 12, 29, 19, 51, 10, 370000), datetime.datetime(2016, 4, 16, 14, 13, 36, 297000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), '', '', '', '', '', '0', '', None, None, None, None, '', '', '', '', '--None--', '0', '0', 4, None, None, '', '', '', '--None--', '', '', 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, 'Open', 70532974, '', None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692414, 30000011, 'Rajeev', 'rajeev', 'R', 'rajeev@digite.com', datetime.datetime(2015, 12, 29, 19, 52, 37, 833000), datetime.datetime(2015, 12, 29, 23, 53, 40, 267000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), None, None, None, None, None, '0', None, None, None, None, None, None, None, None, '', '--None--', '0', '0', 3, None, None, None, None, None, '--None--', None, None, 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, None, 70532964, None, None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692415, 30000011, 'Avishkar', 'avishkar', 'K', 'avishkar@digite.com', datetime.datetime(2016, 4, 16, 16, 44, 52, 930000), datetime.datetime(2018, 10, 29, 0, 42, 58, 200000), b"\xcc'9\xc6O\xef\xb1\x99", None, 'Open', '', '', Decimal('1.00'), '', '', '', '', '', '0', '', None, None, None, None, '', '', '', '', '--None--', '0', '0', 2, None, None, '', '', '', '', '', '', 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, 'Open', 70532971, '', None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')
# row = (70692916, 30000011, 'PM', 'testPM', '1', 'testpm@digite.com', datetime.datetime(2018, 10, 9, 12, 43, 23, 887000), datetime.datetime(2018, 10, 9, 12, 54, 54, 207000), b"\xcc'9\xc6O\xef\xb1\x99", datetime.datetime(2019, 10, 9, 12, 44, 9, 857000), 'Open', 'common', '111111', Decimal('50.00'), 'Digite Infotech', 'Mr', 'BTM Bangalore', 'Bangalore', 'Karnataka', 'KEY_India', '560029', None, None, '08044442222', None, '', '', '', 'DS119', 'Manager', 'Engineering', '30017826', 5, None, None, 'Lavale road', 'Bangalore', 'Karnataka', 'KEY_India', '560029', '', 'en_US', 'en_US', 'en_US', 'IST', 'English', 70620564, 'Open', 70532964, '', None, '<p><img src="ImageRenderer?ImageID=-1" width="100" height="100"/></p>')

# %% [markdown]
# #### Database connection with My SQL

# %%
import MySQLdb
 
db = MySQLdb.connect(host="localhost",  # your host 
                     user="root",       # username
                     passwd="root",     # password
                     db="sakila")   # name of the database
 
# Create a Cursor object to execute queries.
cur = db.cursor()
 
# Select data from table using SQL query.
cur.execute("SELECT * FROM actor")
 
# print the first and second columns      
for row in cur.fetchall() :
    print row[0], " ", row[1]
