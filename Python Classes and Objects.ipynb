# %% [markdown]
# # Python Classes and Objects

# %% [raw]
# >>Python is an object-oriented Programming language.
# >>Almost everything in Python is an object, with its properties and methods.
# >>The basic idea behind an object-oriented programming (OOP) is to combine both data and associated procedures (known as methods) into a single unit which operate on the data.
# >>Such a unit is called an object.

# %% [raw]
# An object has two characteristics:
# 1.attributes
# 2.behavior
#
# Example:
# Peacock is an object,
#
# name, age, color >>>are attributes
# singing, dancing >>>are behavior

# %% [raw]
# In Python, the concept of OOP follows some basic principles:
#
# Inheritance  : A process of using details from a new class without modifying existing class.
# Encapsulation and Abstraction     Hiding the private details of a class from other objects.
# Polymorphism      A concept of using common operation in different ways for different data input.

# %% [markdown]
# **Class**

# %% [raw]
# >>In object oriented programming classes and objects are the main features.
# >>A class creates a new data type and objects are instances of a class which follows the definition     given inside the class
# >>A class is a blueprint for the object.
# >>A class definition starts with the keyword 'class' followed by the name of the class and a colon.

# %%
#Example:
class Student:
        stu_class = 'V'
        stu_roll_no = 12
        stu_name = "David"

# %%
print(type(Student))
# Out:
# <class 'type'>

# %% [markdown]
# **Object**

# %% [raw]
# >>An object (instance) is an instantiation of a class. When class is defined, only the description for   the object is defined. Therefore, no memory or storage is allocated.
# >>Object is simply a collection of data (variables) and methods (functions) that act on those data.     And, class is a blueprint for the object.
# >>The procedure to create an object is similar to a function call.

# %%
#Example:

#Create an object named p1, and print the value of x:
#I use the class named myClass to create objects:

class MyClass:
  x = 5

p1 = MyClass()
print(p1.x)
# Out:
# 5

# %% [markdown]
# **Constructors in Python**

# %% [raw]
# >>Class functions that begins with double underscore (__) are called special functions as they have special meaning.
#
# >> All classes have a inbuilt function called __init__(),this special function gets called whenever a   new object of that class is instantiated.
#
# >>  We normally use it to initialize all the variables.

# %%
#Example
#Create a class named Person, use the __init__() function to assign values for name and age:

class Person:
  def __init__(self, name, age):#the first argument of the function in class must be the object itself. This is called self.
    self.name = name
    self.age = age

p1 = Person("Amit", 36)

print(p1.name)
print(p1.age)
# Out:
# Amit
# 36

# %% [markdown]
# **Self Parameter**

# %% [raw]
# The self parameter is a reference to the class itself, and is used to access variables that belongs to the class.
#
# It is not neccessary to call it as self, you can call it by any name, but it has to be the first parameter of any function in the class

# %% [markdown]
# **Modify Object Properties**

# %%
#We can modify properties on objects like this:
#Example
#Set the age of p1 to 40:

p1.age = 40
print(p1.age)
# Out:
# 40

# %% [markdown]
# **Delete Object Properties**

# %% [markdown]
# You can delete properties on objects by using the del keyword:

# %%
#Example
#Delete the age property from the p1 object:

del p1.age
print(p1.age)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-34fdab4e4147> in <module>()
#       4
#       5 del p1.age
# ----> 6 print(p1.age)
#
# AttributeError: 'Person' object has no attribute 'age'

# %% [markdown]
# **Delete Objects**

# %% [markdown]
# We can delete objects by using the del keyword:

# %%
#Example
#Delete the p1 object:

del p1
print(p1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-03d0b2b2203c> in <module>()
#       3
#       4 del p1
# ----> 5 print(p1)
#
# NameError: name 'p1' is not defined

# %% [markdown]
# **Inheritance**

# %% [markdown]
# Inheritance is a way of creating new class for using details of existing class without modifying it. The newly formed class is a derived class (or child class). Similarly, the existing class is a base class (or parent class).
#
#
#
# ![image.png](attachment:image.png)

# %%
# parent class
class Bird:
    
    def __init__(self):
        print("BirD is ready")

    def whoisThis(self):
        print("Bird")

    def swim(self):
        print("Swim faster")

# child class
class Ostrich(Bird):

    def __init__(self):
        # call super() function
        super().__init__()
        super().swim()
        
        print("Ostrich is ready")

    def whoisThis(self):
        super().whoisThis()
        print("Ostrich")

    def run(self):
        
        print("Run faster")
        
a = Ostrich()
a.whoisThis()
a.swim()
a.run()
# Out:
# BirD is ready
# Swim faster
# Ostrich is ready
# Bird
# Ostrich
# Swim faster
# Run faster

# %% [raw]
# In the above program, we created two classes i.e. Bird (parent class) and Ostrich (child class). The child class inherits the functions of parent class. We can see this from swim() method. Again, the child class modified the behavior of parent class. We can see this from whoisThis() method. Furthermore, we extend the functions of parent class, by creating a new run() method.
#
# Additionally, we use super() function before __init__() method. This is because we want to pull the content of __init__() method from the parent class into the child class.

# %% [markdown]
# **Python Multiple Inheritance**

# %% [raw]
# >>A class can inherit from more than one class. This is called multiple multiple inheritance.
# >>In multiple inheritance, the features of all the base classes are inherited into the derived class. >>The syntax for multiple inheritance is similar to single inheritance.

# %%
#Example
class Base1:
    pass

class Base2:
    pass

class MultiDerived(Base1, Base2):
    pass

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The class MultiDerived inherits from both Base1 and Base2.

# %% [markdown]
# **Multilevel Inheritance in Python**

# %% [raw]
#  we can also inherit form a derived class. This is called multilevel inheritance. It can be of any depth in Python.
#
# In multilevel inheritance, features of the base class and the derived class is inherited into the new derived class.

# %%
#Example:
class Base:
    pass

class Derived1(Base):
    pass

class Derived2(Derived1):
    pass

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Derived1 is derived from Base, and Derived2 is derived from Derived1.

# %% [markdown]
# **Encapsulation**

# %% [raw]
# Using OOP in Python, we can restrict access to methods and variables. This prevent data from direct modification which is called encapsulation. In Python, we denote private attribute using underscore as prefix i.e single “ _ “ or double “ __“.

# %%
class Computer:

    def __init__(self):
        self.__maxprice = 1000

    def sell(self):
        print("Selling Price: {}".format(self.__maxprice))

    def setMaxPrice(self, price):
        self.__maxprice = price

c = Computer()
c.sell()

# change the price
c.__maxprice = 1300
c.sell()

# using setter function
c.setMaxPrice(1500)
c.sell()
# Out:
# Selling Price: 1000
# Selling Price: 1000
# Selling Price: 1500

# %% [raw]
# In the above program, we defined a class Computer. We use __init__() method to store the maximum selling price of computer. We tried to modify the price. However, we can’t change it because Python treats the __maxprice as private attributes. To change the value, we used a setter function i.e setMaxPrice() which takes price as parameter.

# %% [markdown]
# **Polymorphism**

# %% [raw]
# # Polymorphism is an ability (in OOP) to use common interface for multiple form (data types).
#
# Suppose, we need to colour a shape, there are multiple shape option (rectangle, square, circle). However we could use same method to colour any shape. This concept is called Polymorphism.

# %%
class Parrot:

    def fly(self):
        print("Parrot can fly")
    
    def swim(self):
        print("Parrot can't swim")

class Penguin:

    def fly(self):
        print("Penguin can't fly")
    
    def swim(self):
        print("Penguin can swim")

# common interface
def flying_test(bird):
    bird.fly()

#instantiate objects
a = Parrot()
b = Penguin()

# passing the object
flying_test(a)
flying_test(b)

# %% [raw]
# In the above program, we defined two classes Parrot and Penguin. Each of them have common method fly() method. However, their functions are different. To allow polymorphism, we created common interface i.e flying_test() function that can take any object. Then, we passed the objects a and b in the flying_test() function, it ran effectively.
